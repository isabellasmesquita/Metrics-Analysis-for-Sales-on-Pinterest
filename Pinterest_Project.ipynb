# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Load the data and EDA

# %%
# Load the dataset
df = pd.read_csv('C:/Users/isabe/OneDrive/Ambiente de Trabalho/project module 1/pinterest_finalised.csv')

display(df)

# Visualize the first rows
display(df.head())

# General information about the dataset
display(df.info())

# Descriptive statistics
display(df.describe())
# Out:
#                      id                                        description  \
# 0     21181060741374444
# 1     21181060741360357
# 2     21181060741360356  The Toppu Mini Bowl is part of the popular Top...
# 3     21181060741360355
# 4     21181060741360353
# ...                 ...                                                ...
# 4995  91620173664083654
# 4996  91620173664083653
# 4997  91620173664083651
# 4998  91620173664083644
# 4999  91620173664083642
#
#                                   title  repin_count
# 0                                   NaN            0
# 1                                   NaN            0
# 2     Toppu Mini Bowl in Caramel / Rose            0
# 3                                     𐀔            0
# 4                                   NaN            0
# ...                                 ...          ...
# 4995                                NaN            3
# 4996                                NaN            3
# ...

# %%
pin = pd.read_csv('C:/Users/isabe/OneDrive/Ambiente de Trabalho/project module 1/pinterest_Q_A.csv')

display(pin)

# Visualize the first rows
display(pin.head())

# General information about the dataset
display(pin.info())

# Descriptive statistics
display(pin.describe())
# Out:
#     content_types  posting_frequency                             keywords  \
# 0          images                 30                     rustic_decor,DIY
# 1          videos                 15      gift_ideas,sustainable_products
# 2    infographics                  5                  tutorials,how_to_do
# 3          images                 20                     handmade_jewelry
# 4          images                 15                                  DIY
# 5   infographics                  20     make-up tutorials,natural_beauty
# 6         images                  15                         modern_decor
# 7          videos                 30          boho_style,minimalist_decor
# 8          images                 20    women_fashion,comfortable_clothes
# 9         videos                  30         healthy_cooking,easy_recipes
# 10         images                 15                        vintage_decor
# 11         images                 20  sustainable_handmade,creative_decor
# ...

# %% [markdown]
# ## Data cleaning

# %%
# Checking for missing values in each column
print(df.isnull().sum())

# Dropping rows where 'description' is missing, as it's relevant for analysis
df_cleaned = df.dropna(subset=['description'])

# Viewing the information of the cleaned dataset
print(df_cleaned.info())
# Out:
# id                0
# description       3
# title          3494
# repin_count       0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 4997 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4997 non-null   int64
#  1   description  4997 non-null   object
#  2   title        1506 non-null   object
#  3   repin_count  4997 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 195.2+ KB
# None

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Simulated DataFrame with content types and engagement values
data = {
    'Content_Type': ['Image', 'Video', 'Infographic', 'Image', 'Video', 'Infographic', 'Image', 'Video'],
    'Engagement': [100, 200, 150, 300, 220, 180, 250, 190]
}

df = pd.DataFrame(data)

# Group by content type and calculate the average engagement
engagement_by_type = df.groupby('Content_Type')['Engagement'].mean()

# Reset the index of the resulting DataFrame
engagement_by_type_reset = engagement_by_type.reset_index()

# Create a bar plot to visualize the average engagement by content type
plt.figure(figsize=(10, 6))
plt.bar(engagement_by_type_reset['Content_Type'], engagement_by_type_reset['Engagement'], color='skyblue')
plt.xlabel('Content Type')
plt.ylabel('Average Engagement')
plt.title('Average Engagement by Content Type on Pinterest')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data example
data = {
    'content_type': ['Image Only', 'Video Only', 'Both'],
    'repin_count': [200, 150, 200]
}
df = pd.DataFrame(data)

# Create the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='content_type', y='repin_count')

# Remove the last bar (do not display it)
plt.xticks(ticks=[0, 1, 2], labels=['Image Only', 'Video Only', 'Both'])

plt.title('Average Repins by Content Type')
plt.xlabel('Content Type')
plt.ylabel('Average Repins')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset
df = pd.read_csv('C:/Users/isabe/OneDrive/Ambiente de Trabalho/project module 1/pinterest_finalised.csv')

# Display the column names
print(df.columns)

# Create the content_type column based on the description or title
def determine_content_type(row):
    # Check if the description is not NaN
    if isinstance(row['description'], str):  # Confirm it is a string
        if 'image' in row['description'].lower():
            return 'Image Only'
        elif 'video' in row['description'].lower():
            return 'Video Only'
    return 'Both'  # or another type you want to define when the condition is not met

# Apply the function to create the new column
df['content_type'] = df.apply(determine_content_type, axis=1)

# Calculate the average repins by content type
engagement_by_type = df.groupby('content_type')['repin_count'].mean().reset_index()

# Create the bar chart
plt.figure(figsize=(10, 6))

# Plot the data
sns.barplot(data=engagement_by_type, x='content_type', y='repin_count')

plt.title('Average Repins by Content Type')
plt.xlabel('Content Type')
plt.ylabel('Average Repins')

plt.show()
# Out:
# Index(['id', 'description', 'title', 'repin_count'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import re

# Load the CSV file
df = pd.read_csv('pinterest_finalised.csv', encoding='MacRoman')

# Check the data
print("Total number of rows:", len(df))
print("\nNumber of non-null values in each column:")
print(df.notnull().sum())

# Function to clean the text
def clean_text(text):
    if isinstance(text, str):
        # Remove special characters and convert to lowercase
        return re.sub(r'[^\w\s]', '', text.lower())
    return ''

# Clean and count the words in the titles
words = df['title'].fillna('').apply(clean_text).str.split(expand=True).stack().value_counts()

print("\nThe 20 most common words in the titles:")
print(words.head(20))

# Plot the 20 most common words
plt.figure(figsize=(12, 6))
words.head(20).plot(kind='bar')
plt.title('20 Most Common Words in Pinterest Titles')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Total number of rows: 5000
#
# Number of non-null values in each column:
# id             5000
# description    4997
# title          1506
# repin_count    5000
# dtype: int64
#
# The 20 most common words in the titles:
# the        324
# for        297
# shop       260
# to         211
# in         180
# your       178
# fall       144
# a          129
# you        120
# and        116
# with       104
# this        89
# new         86
# dresses     82
# at          79
# chic        75
# is          69
# these       66
# need        64
# style       60
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import re

# Load the CSV file
df = pd.read_csv('pinterest_finalised.csv', encoding='MacRoman')

# Function to clean the text
def clean_text(text):
    if isinstance(text, str):
        return re.sub(r'[^\w\s]', '', text.lower()).split()
    return []

# Create a dictionary to store the repin count for each word
word_repin_count = defaultdict(list)

# Iterate over the rows of the DataFrame
for _, row in df.iterrows():
    title = row['title']
    repin_count = row['repin_count']
    
    if pd.notna(title):
        words = clean_text(title)
        for word in words:
            word_repin_count[word].append(repin_count)

# Calculate the average repins for each word
word_avg_repins = {word: sum(counts) / len(counts) for word, counts in word_repin_count.items() if len(counts) > 10}

# Sort words by average repins
sorted_words = sorted(word_avg_repins.items(), key=lambda x: x[1], reverse=True)

# Take the top 20 words
top_20_words = sorted_words[:20]

# Create separate lists for words and average repins
words = [word for word, _ in top_20_words]
avg_repins = [avg for _, avg in top_20_words]

# Create the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=words, y=avg_repins)
plt.title('Top 20 Words by Average Repins')
plt.xlabel('Words')
plt.ylabel('Average Repins')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Print the results
print("Top 20 words by average repins:")
for word, avg in top_20_words:
    print(f"{word}: {avg:.2f}")

# Calculate the correlation between title length and repin count
df['title_length'] = df['title'].fillna('').apply(len)
correlation = df['title_length'].corr(df['repin_count'])

print(f"\nCorrelation between title length and number of repins: {correlation:.2f}")

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['title_length'], df['repin_count'], alpha=0.5)
plt.title('Relationship Between Title Length and Number of Repins')
plt.xlabel('Title Length')
plt.ylabel('Number of Repins')
plt.show()
# Out:
# Top 20 words by average repins:
# denim: 24.31
# our: 14.62
# picks: 14.36
# joy: 13.96
# skirts: 13.72
# boots: 13.61
# pants: 12.63
# green: 10.69
# jackets: 9.54
# blue: 9.06
# color: 9.00
# accessories: 8.64
# oh: 8.64
# miu: 8.60
# is: 8.39
# jacket: 7.62
# luxury: 7.54
# bag: 7.09
# out: 6.93
# suiting: 6.60
#
# Correlation between title length and number of repins: -0.05

# %% [markdown]
# Q&A

# %%
# Calculating average frequencies for items that appear twice
content_types_unique = ['Images', 'Videos', 'Infographics']
posting_frequencies_avg = [
    np.mean([23, 15]),  # Average for Images
    np.mean([23, 45]),  # Average for Videos
    5  # Infographics (only appears once)
]

# Pastel colors
pastel_colors = ['#AEC6CF', '#FFB6C1', '#C3B1E1']

plt.figure(figsize=(8, 6))
plt.bar(content_types_unique, posting_frequencies_avg, color=pastel_colors)
plt.title('Average Posting Frequency by Content Type')
plt.xlabel('Content Type')
plt.ylabel('Average Posting Frequency')

plt.show()

# Print the exact values (not shown on the graph)
print("Average Posting Frequencies:")
for content, freq in zip(content_types_unique, posting_frequencies_avg):
    print(f"{content}: {freq:.1f}")
# Out:
# Average Posting Frequencies:
# Images: 19.0
# Videos: 34.0
# Infographics: 5.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Load the data
qa = pd.read_csv('pinterest_Q_A.csv', encoding='ascii')

# Function to get all unique keywords
def get_all_keywords(series):
    return [keyword.strip() for keywords in series.dropna() for keyword in keywords.split(',')]

# Get all keywords
all_keywords = get_all_keywords(qa['keywords'])

# Count keyword frequencies
keyword_counts = Counter(all_keywords)

# Get top 15 keywords
top_15_keywords = dict(keyword_counts.most_common(15))

# Create a horizontal bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x=list(top_15_keywords.values()), y=list(top_15_keywords.keys()), palette='viridis')
plt.title('Top 15 Keywords - Horizontal Bar Plot')
plt.xlabel('Frequency')
plt.ylabel('Keywords')
plt.show()
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_8880\495457870.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(top_15_keywords.values()), y=list(top_15_keywords.keys()), palette='viridis')

# %%
# Create a pie chart for the distribution of trends
plt.figure(figsize=(8, 8))
qa['trends'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Distribution of Trends')
plt.ylabel('')  # Hide the y-label
plt.show()

# Assuming there's a time component, create a line plot for trends over time
# For demonstration, let's assume there's a 'date' column in the dataframe
# If not, this part will be skipped
if 'date' in qa.columns:
    qa['date'] = pd.to_datetime(qa['date'])
    trend_over_time = qa.groupby([qa['date'].dt.to_period('M'), 'trends']).size().unstack().fillna(0)
    trend_over_time.plot(figsize=(12, 6))
    plt.title('Trends Over Time')
    plt.xlabel('Time')
    plt.ylabel('Frequency')
    plt.show()

# Create a heatmap to visualize correlations between trends and other columns
# For demonstration, let's assume there's a numerical column to correlate with
# If not, this part will be skipped
if 'some_numerical_column' in qa.columns:
    correlation_data = df[['trends', 'some_numerical_column']].copy()
    correlation_data['trends'] = correlation_data['trends'].astype('category').cat.codes
    sns.heatmap(correlation_data.corr(), annot=True, cmap='coolwarm')
    plt.title('Correlation Heatmap')
    plt.show()
